# %%
from scipy import optimize
import matplotlib.pyplot as plt

# %%
def f1(x):
    return (x**2 -  1)

# %%
x0 = 2.5

opt2 = optimize.minimize(f1, x0, method='CG')  #  'CG' (Conjugate Gradient)
opt1 = optimize.minimize(f1, x0, method='L-BFGS-B')
#  Broyden-Fletcher-Goldfarb-Shanno (BFGS) for limited memory

opt = optimize.minimize_scalar(f1)

print("By CG: ", opt2)
print("By BFGS:  ", opt1)
print("By 1d:  ", opt)
# Out:
# By CG:   message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: -0.9999999999999836
#        x: [-1.281e-07]
#      nit: 1
#      jac: [-2.459e-07]
#     nfev: 6
#     njev: 3
# By BFGS:     message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 0
#       fun: -1.0
#         x: [ 0.000e+00]
#       nit: 2
#       jac: [ 1.110e-08]
#      nfev: 6
#      njev: 3
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
# By 1d:    message:
#           Optimization terminated successfully;
#           The returned value satisfies the termination criteria
#           (using xtol = 1.48e-08 )
#  success: True
#      fun: -1.0
#        x: 4.4020875904303335e-09
#      nit: 36
#     nfev: 39
